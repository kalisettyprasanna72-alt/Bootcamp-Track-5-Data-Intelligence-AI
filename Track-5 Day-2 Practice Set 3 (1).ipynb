# %%
students = [
    {"name": "Aarav Sharma", "marks": 78},
    {"name": "Priya Patel", "marks": 92},
    {"name": "Rohan Gupta", "marks": 65},
    {"name": "Sneha Reddy", "marks": 88},
    {"name": "Vikram Singh", "marks": 45},
    {"name": "Ananya Iyer", "marks": 95},
    {"name": "Karan Malhotra", "marks": 72},
    {"name": "Meera Nair", "marks": 81},
    {"name": "Arjun Khan", "marks": 58},
    {"name": "Ishita Joshi", "marks": 89},
]

# %%
for student in students:
    print(student["name"])
# Out:
# Aarav Sharma
# Priya Patel
# Rohan Gupta
# Sneha Reddy
# Vikram Singh
# Ananya Iyer
# Karan Malhotra
# Meera Nair
# Arjun Khan
# Ishita Joshi

# %%
total_marks = 0

for student in students:
    total_marks += student["marks"]

print("Total Marks =", total_marks)
# Out:
# Total Marks = 763

# %%
top_student = students[0]

for student in students:
    if student["marks"] > top_student["marks"]:
        top_student = student

print(top_student)
# Out:
# {'name': 'Ananya Iyer', 'marks': 95}

# %%
for student in students:
    if student["marks"] >= 80:
        print(student)
# Out:
# {'name': 'Priya Patel', 'marks': 92}
# {'name': 'Sneha Reddy', 'marks': 88}
# {'name': 'Ananya Iyer', 'marks': 95}
# {'name': 'Meera Nair', 'marks': 81}
# {'name': 'Ishita Joshi', 'marks': 89}

# %%
for student in students:
    marks = student["marks"]

    if marks >= 90:
        student["grade"] = "A"
    elif marks >= 75:
        student["grade"] = "B"
    else:
        student["grade"] = "C"

for student in students:
    print(student)
# Out:
# {'name': 'Aarav Sharma', 'marks': 78, 'grade': 'B'}
# {'name': 'Priya Patel', 'marks': 92, 'grade': 'A'}
# {'name': 'Rohan Gupta', 'marks': 65, 'grade': 'C'}
# {'name': 'Sneha Reddy', 'marks': 88, 'grade': 'B'}
# {'name': 'Vikram Singh', 'marks': 45, 'grade': 'C'}
# {'name': 'Ananya Iyer', 'marks': 95, 'grade': 'A'}
# {'name': 'Karan Malhotra', 'marks': 72, 'grade': 'C'}
# {'name': 'Meera Nair', 'marks': 81, 'grade': 'B'}
# {'name': 'Arjun Khan', 'marks': 58, 'grade': 'C'}
# {'name': 'Ishita Joshi', 'marks': 89, 'grade': 'B'}
