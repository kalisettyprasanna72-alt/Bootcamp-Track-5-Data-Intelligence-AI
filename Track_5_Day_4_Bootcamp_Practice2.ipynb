# %% [markdown]
# <a href="https://colab.research.google.com/github/kalisettyprasanna72-alt/Bootcamp-Track-5-Data-Intelligence-AI/blob/main/Track_5_Day_4_Bootcamp_Practice2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
df = pd.read_csv('Heart_disease_cleveland_new.csv')
df.head()
# Out:
#    age  sex  cp  trestbps  chol  fbs  restecg  thalach  exang  oldpeak  slope  \
# 0   63    1   0       145   233    1        2      150      0      2.3      2
# 1   67    1   3       160   286    0        2      108      1      1.5      1
# 2   67    1   3       120   229    0        2      129      1      2.6      1
# 3   37    1   2       130   250    0        0      187      0      3.5      2
# 4   41    0   1       130   204    0        2      172      0      1.4      0
#
#    ca  thal  target
# 0   0     2       0
# 1   3     1       1
# 2   2     3       1
# 3   0     1       0
# 4   0     1       0

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
sns.histplot(df['age'], kde=True)
plt.title("Age Distribution")
plt.show()

# %%
sns.histplot(df['chol'],kde=True)
plt.title("Cholesterol Distribution")
plt.show()

# %%
sns.histplot(data=df, x='chol', hue='target', kde="True")
# Out:
# <Axes: xlabel='chol', ylabel='Count'>

# %%
sns.histplot(data=df, x='age', hue='target', kde=True)
# Out:
# <Axes: xlabel='age', ylabel='Count'>

# %%
sns.boxplot(x=df['trestbps'])
plt.title("Resting Blood Pressure")
plt.show()

# %%
sns.boxplot(data=df, x='chol')
plt.title("Cholesterol")
plt.show()

# %%
sns.boxplot(x='target', y='chol', data=df)
plt.title("Target and Cholesterol")
plt.show()

# %%
sns.barplot(data=df, x='target', y='age')
plt.title("Target and Age")
plt.show()

# %%
sns.barplot(data=df, x="target", y="age", hue="target")
plt.title("Target and Age Distribution")
plt.xlabel("Target Categories")
plt.ylabel("Average Age")
plt.show()

# %%
sns.countplot(data=df, x='target')
# Out:
# <Axes: xlabel='target', ylabel='count'>

# %%
sns.scatterplot(data=df, x='age', y='chol', hue="age" )
# Out:
# <Axes: xlabel='age', ylabel='chol'>

# %%
sns.lineplot(data=df, x=df.index, y='thalach')
plt.title("Heart rate values change across dataset rows")
plt.show()

# %%
sns.lineplot(data=df.sort_values('age'), x='age', y='thalach')
# Out:
# <Axes: xlabel='age', ylabel='thalach'>

# %%
corr = df.corr()
plt.figure(figsize=(12, 8)) # 👈 Increase size here
sns.heatmap(corr, annot=True, cmap='coolwarm')
plt.title("Correlation Matrix")
plt.show()

# %%
corr = df.corr()
target_corr = corr[['target']].sort_values(by='target', ascending=False)
plt.figure(figsize=(6, 10))
sns.heatmap(target_corr, annot=True, cmap='coolwarm')
plt.title("Correlation of All Features with Target")
plt.show()
